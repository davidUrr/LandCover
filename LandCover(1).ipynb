# %%
from PIL import Image #import Python Image Library
import numpy as np
import os
import glob
import re
import keras
import pandas as pd
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras.utils import np_utils
from keras import backend as K
import mlutils
import tensorflow as tf
import matplotlib.pyplot as plt
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.optimizers import Adam
# %matplotlib inline
# Out:
# Using TensorFlow backend.
# /opt/miniconda/lib/python2.7/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# /opt/miniconda/lib/python2.7/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# /opt/miniconda/lib/python2.7/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %% [markdown]
# ## Funciones creadas para graficar

# %%
# plot the evolution of Loss and Acuracy on the train and validation sets
def plotevol():
    import matplotlib.pyplot as plt

    plt.figure(figsize=(20,10))
    plt.subplot(1, 2, 1)
    plt.suptitle('Optimizer : Adam', fontsize=10)
    plt.ylabel('Loss', fontsize=16)
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.legend(loc='upper right')

    plt.subplot(1, 2, 2)
    plt.ylabel('Accuracy', fontsize=16)
    plt.plot(history.history['acc'], label='Training Accuracy')
    plt.plot(history.history['val_acc'], label='Validation Accuracy')
    plt.legend(loc='lower right')
    return plt.show()

# %% [markdown]
# ## Descarga de imágenes

# %% [markdown]
# Se descargan 27000 imágenes del proyecto EuroSAT y se descomprimen

# %%
# !mkdir ImgsSat
# !wget http://madm.dfki.de/files/sentinel/EuroSAT.zip -P ImgsSat
# !unzip ImgsSat/EuroSAT.zip -d ImgsSat
# Out:
# --2019-04-11 07:05:26--  http://madm.dfki.de/files/sentinel/EuroSAT.zip
# Resolving madm.dfki.de (madm.dfki.de)... 131.246.195.183
# Connecting to madm.dfki.de (madm.dfki.de)|131.246.195.183|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 94280567 (90M) [application/zip]
# Saving to: ‘ImgsSat/EuroSAT.zip’
#
# EuroSAT.zip         100%[===================>]  89.91M  12.3MB/s    in 17s
#
# 2019-04-11 07:05:52 (5.43 MB/s) - ‘ImgsSat/EuroSAT.zip’ saved [94280567/94280567]
#
# Archive:  ImgsSat/EuroSAT.zip
#    creating: ImgsSat/2750/
#    creating: ImgsSat/2750/River/
#   inflating: ImgsSat/2750/River/River_479.jpg
#   inflating: ImgsSat/2750/River/River_2178.jpg
#   inflating: ImgsSat/2750/River/River_65.jpg
#   inflating: ImgsSat/2750/River/River_1643.jpg
#   inflating: ImgsSat/2750/River/River_191.jpg
#   inflating: ImgsSat/2750/River/River_636.jpg
#   inflating: ImgsSat/2750/River/River_2490.jpg
#   inflating: ImgsSat/2750/River/River_2337.jpg
#   inflating: ImgsSat/2750/River/River_982.jpg
#   inflating: ImgsSat/2750/River/River_257.jpg
#   inflating: ImgsSat/2750/River/River_1585.jpg
#   inflating: ImgsSat/2750/River/River_1222.jpg
#   inflating: ImgsSat/2750/River/River_1926.jpg
#   inflating: ImgsSat/2750/River/River_1554.jpg
#   inflating: ImgsSat/2750/River/River_953.jpg
#   inflating: ImgsSat/2750/River/River_521.jpg
#   inflating: ImgsSat/2750/River/River_286.jpg
#   inflating: ImgsSat/2750/River/River_2441.jpg
#   inflating: ImgsSat/2750/River/River_140.jpg
#   inflating: ImgsSat/2750/River/River_1135.jpg
#   inflating: ImgsSat/2750/River/River_1692.jpg
#   inflating: ImgsSat/2750/River/River_2020.jpg
#   inflating: ImgsSat/2750/River/River_1470.jpg
#   inflating: ImgsSat/2750/River/River_1802.jpg
#   inflating: ImgsSat/2750/River/River_405.jpg
jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1335.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2220.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1831.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1443.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2137.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1022.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1785.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1969.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_381.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_426.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_854.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_350.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_885.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2378.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_6.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_731.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_62.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1728.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_274.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1349.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_615.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1398.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_163.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_970.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_502.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2472.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1567.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1915.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2013.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_828.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1106.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1670.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1211.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2304.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_273.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1088.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_612.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1438.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_164.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1059.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_505.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_977.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2475.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1912.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1560.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2014.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1101.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1677.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_19.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1216.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2303.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1753.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1332.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1495.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2227.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_118.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1444.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1836.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2130.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1782.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_579.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1025.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2409.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_853.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_421.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_386.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_2068.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_882.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_357.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_1.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_65.jpg
#   inflating: ImgsSat/2750/PermanentCrop/PermanentCrop_736.jpg

# %% [markdown]
# ## Separación de las imágenes en train y test

# %%
## (En máquina virtual tarda unos # minutos)
import random
import shutil

random.seed(28) #42
# variables
path_to_all_images = "ImgsSat/2750" #Carpeta donde están las imágenes
path_to_split_datasets = "split" #Carpeta donde se van a separar
percentage_validation = 0.35 # percentage of validation data (between 0 an 1) #0.3
delete_old_path_to_split_datasets = True #Borrar los train-test anteriores

# Rutas a las carpetas
path_to_home = os.path.expanduser("~")
path_to_all_images = path_to_all_images.replace("~", path_to_home)
path_to_split_datasets = path_to_split_datasets.replace("~", path_to_home)
# Borra y crea carpetas
shutil.rmtree('split')
os.makedirs('split')
if delete_old_path_to_split_datasets and os.path.isdir(path_to_split_datasets):
    shutil.rmtree(path_to_split_datasets)
path_to_train = os.path.join(path_to_split_datasets, "train")
path_to_validation = os.path.join(path_to_split_datasets, "test")
if not os.path.isdir(path_to_train):
    os.makedirs(path_to_train)
if not os.path.isdir(path_to_validation):
    os.makedirs(path_to_validation)

# Copia los archivos
sub_dirs = [sub_dir for sub_dir in os.listdir(path_to_all_images)
            if os.path.isdir(os.path.join(path_to_all_images, sub_dir))] #Clases
for sub_dir in mlutils.pbar()(sub_dirs):
    # list and shuffle images in class directories
    current_dir = os.path.join(path_to_all_images, sub_dir)
    files = os.listdir(current_dir)
    random.shuffle(files)
    # split files into train and validation set
    split_idx = int(len(files)*percentage_validation)
    files_for_validation = files[:split_idx]
    files_for_train = files[split_idx:]
    # copy files to path_to_split_datasets
    if not os.path.isdir(os.path.join(path_to_train, sub_dir)):
        os.makedirs(os.path.join(path_to_train, sub_dir))
    if not os.path.isdir(os.path.join(path_to_validation, sub_dir)):
        os.makedirs(os.path.join(path_to_validation, sub_dir))
    for file in files_for_train:
        shutil.copy2(os.path.join(current_dir, file),
                     os.path.join(path_to_train, sub_dir))
    for file in files_for_validation:
        shutil.copy2(os.path.join(current_dir, file),
                     os.path.join(path_to_validation, sub_dir))
# Out:
# 100% (10 of 10) |#########################| Elapsed Time: 0:08:20 Time: 0:08:20

# %% [markdown]
# ## Categorías con el número de imágenes

# %%
#nombres de categorías
downloads = "Images" #Direcciones donde se guardarán las imgs
traintest_imgs = "split"
train_pct = .7
classdirs = !find $downloads -type d
classdirs = [i.split("/")[-1] for i in classdirs if i!=downloads]
#Saber número de imágenes para train y test de cada categoría
for classdir in classdirs:
    print classdir
    files = !find  $traintest_imgs/train/$classdir -type f
    print "      ",len(files), "train images"
    files = !find  $traintest_imgs/test/$classdir -type f
    print "      ",len(files), "test images"
# Out:
# AnnualCrop
#        1950 train images
#        1050 test images
# Forest
#        1950 train images
#        1050 test images
# HerbaceousVegetation
#        1950 train images
#        1050 test images
# Highway
#        1625 train images
#        875 test images
# Industrial
#        1625 train images
#        875 test images
# Pasture
#        1300 train images
#        700 test images
# PermanentCrop
#        1625 train images
#        875 test images
# Residential
#        1950 train images
#        1050 test images
# River
#        1625 train images
#        875 test images
# SeaLake
#        1950 train images
#        1050 test images

# %% [markdown]
# ## Generador de las imágenes para la red

# %%
datagen_test = ImageDataGenerator(rescale=1./255)
datagen_train = ImageDataGenerator(rescale=1./255)

# %%
batch_size = 32
input_shape = 64
generator_train = datagen_train.flow_from_directory(directory="split/train",
                                                    target_size=(input_shape, input_shape),
                                                    batch_size=batch_size,
                                                    #interpolation = "bilinear",
                                                    class_mode='categorical')
                                                    #shuffle=True)
# Out:
# Found 17550 images belonging to 10 classes.

# %%
generator_test = datagen_test.flow_from_directory(directory="split/test",
                                                  target_size=(input_shape, input_shape),
                                                  batch_size=batch_size,
                                                  #interpolation = "bilinear",
                                                  class_mode='categorical')#,
                                                  #shuffle=False)
# Out:
# Found 9450 images belonging to 10 classes.

# %% [markdown]
# ## Arquitectura de la red inicial
# 5 capas convolucionales y 2 densas

# %%
from keras import optimizers
def get_conv_model_A(num_classes, img_size=64, compile=True):
    tf.reset_default_graph()
    tf.keras.backend.clear_session()
    print "using",num_classes,"classes"  
    inputs = tf.keras.Input(shape=(img_size,img_size,3), name="input_1")
    layers = tf.keras.layers.Conv2D(96,(11,11), activation="relu", padding="SAME")(inputs) #, padding="SAME"se debería usar padding por
    layers = tf.keras.layers.MaxPool2D(2,2)(layers)
    layers = tf.keras.layers.Conv2D(256,(5,5), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.MaxPool2D(2,2)(layers)
    layers = tf.keras.layers.Conv2D(256,(3,3), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.MaxPool2D(2,2)(layers)
    layers = tf.keras.layers.Conv2D(256,(5,5), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.Conv2D(256,(5,5), activation="relu", padding="SAME")(layers)
    layers = tf.keras.layers.MaxPool2D(3,3)(layers)
    layers = tf.keras.layers.Flatten()(layers)
    layers = tf.keras.layers.Dense(64, activation=tf.nn.relu)(layers)
    layers = tf.keras.layers.Dropout(0.2)(layers)
    layers = tf.keras.layers.Dense(128, activation=tf.nn.relu)(layers)
    predictions = tf.keras.layers.Dense(num_classes, activation=tf.nn.softmax, name="output_1")(layers)
    model = tf.keras.Model(inputs = inputs, outputs=predictions)
    if compile:
        #sgd = optimizers.SGD(lr=0.01, decay=1e-6, momentum=0.9, nesterov=True)
        #Optimizer = tf.keras.optimizers.SGD(lr=1e-3, momentum=0.3, decay=0, nesterov=False)
        #model.compile(optimizer='sgd',#'adam',#Optimizer,
         #             loss='sparse_categorical_crossentropy',#tf.keras.losses.mean_squared_error,
        #              metrics=['accuracy']) adam categorical_crossentropy
        optimizer = Adam(lr=1e-5)
        model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
    return model
num_classes = len(classdirs)
model = get_conv_model_A(num_classes, img_size=input_shape)
print num_classes, input_shape
# Out:
# using 10 classes
# 10 64

# %% [markdown]
# ## Ejecución del modelo

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=generator_train,
                                  epochs=10,
                                  steps_per_epoch=50,
                                  validation_data=generator_test,
                                  validation_steps=40,
                              callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 49/50 [============================>.] - ETA: 3s - loss: 2.2841 - acc: 0.0912
# Epoch 00001: val_acc improved from -inf to 0.09922, saving model to model_weights.h5
# 50/50 [==============================] - 245s 5s/step - loss: 2.2845 - acc: 0.0912 - val_loss: 2.2593 - val_acc: 0.0992
# Epoch 2/10
# 49/50 [============================>.] - ETA: 3s - loss: 2.2413 - acc: 0.1027
# Epoch 00002: val_acc improved from 0.09922 to 0.16953, saving model to model_weights.h5
# 50/50 [==============================] - 214s 4s/step - loss: 2.2413 - acc: 0.1025 - val_loss: 2.2090 - val_acc: 0.1695
# Epoch 3/10
# 49/50 [============================>.] - ETA: 2s - loss: 2.1927 - acc: 0.1594
# Epoch 00003: val_acc improved from 0.16953 to 0.19062, saving model to model_weights.h5
# 50/50 [==============================] - 198s 4s/step - loss: 2.1925 - acc: 0.1600 - val_loss: 2.1535 - val_acc: 0.1906
# Epoch 4/10
# 49/50 [============================>.] - ETA: 2s - loss: 2.1471 - acc: 0.1645
# Epoch 00004: val_acc improved from 0.19062 to 0.23828, saving model to model_weights.h5
# 50/50 [==============================] - 201s 4s/step - loss: 2.1485 - acc: 0.1644 - val_loss: 2.0676 - val_acc: 0.2383
# Epoch 5/10
# 49/50 [============================>.] - ETA: 2s - loss: 2.0715 - acc: 0.2143
# Epoch 00005: val_acc improved from 0.23828 to 0.25703, saving model to model_weights.h5
# 50/50 [==============================] - 194s 4s/step - loss: 2.0733 - acc: 0.2131 - val_loss: 1.9876 - val_acc: 0.2570
# Epoch 6/10
# 49/50 [============================>.] - ETA: 2s - loss: 2.0106 - acc: 0.2404
# Epoch 00006: val_acc did not improve from 0.25703
# 50/50 [==============================] - 195s 4s/step - loss: 2.0101 - acc: 0.2394 - val_loss: 1.9194 - val_acc: 0.2500
# Epoch 7/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.9573 - acc: 0.2506
# Epoch 00007: val_acc improved from 0.25703 to 0.30859, saving model to model_weights.h5
# 50/50 [==============================] - 191s 4s/step - loss: 1.9575 - acc: 0.2506 - val_loss: 1.8574 - val_acc: 0.3086
# Epoch 8/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.8939 - acc: 0.2564
# Epoch 00008: val_acc improved from 0.30859 to 0.39297, saving model to model_weights.h5
# 50/50 [==============================] - 190s 4s/step - loss: 1.8931 - acc: 0.2575 - val_loss: 1.8018 - val_acc: 0.3930
# Epoch 9/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.8310 - acc: 0.3087
# Epoch 00009: val_acc did not improve from 0.39297
# 50/50 [==============================] - 195s 4s/step - loss: 1.8271 - acc: 0.3100 - val_loss: 1.7451 - val_acc: 0.3930
# Epoch 10/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.7719 - acc: 0.3297
# Epoch 00010: val_acc improved from 0.39297 to 0.39766, saving model to model_weights.h5
# 50/50 [==============================] - 202s 4s/step - loss: 1.7760 - acc: 0.3281 - val_loss: 1.6542 - val_acc: 0.3977

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 64, 64, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 64, 64, 96)        34944
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 32, 32, 96)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 32, 256)       614656
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 256)       590080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 8, 8, 256)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 8, 256)         1638656
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 8, 8, 256)         1638656
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 2, 2, 256)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 64)                65600
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               8320
# _________________________________________________________________
# output_1 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 4,592,202
# Trainable params: 4,592,202
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Gráfica del desempeño y la función de pérdida en la corrida

# %%
plotevol()

# %% [markdown]
# # Uso de los pesos de la primera capa de AlexNet

# %% [markdown]
# ## Descarga de los pesos

# %%
# Load the weights into memory
# !mkdir Weights
# !rm Weights/bvlc_alexnet.npy
# !wget http://www.cs.toronto.edu/~guerzhoy/tf_alexnet/bvlc_alexnet.npy -P Weights
# Out:
# mkdir: cannot create directory ‘Weights’: File exists
# --2019-04-21 16:51:28--  http://www.cs.toronto.edu/~guerzhoy/tf_alexnet/bvlc_alexnet.npy
# Resolving www.cs.toronto.edu (www.cs.toronto.edu)... 128.100.3.30
# Connecting to www.cs.toronto.edu (www.cs.toronto.edu)|128.100.3.30|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 243861814 (233M)
# Saving to: ‘Weights/bvlc_alexnet.npy’
#
# bvlc_alexnet.npy    100%[===================>] 232.56M  1.10MB/s    in 3m 11s
#
# 2019-04-21 16:54:40 (1.21 MB/s) - ‘Weights/bvlc_alexnet.npy’ saved [243861814/243861814]

# %% [markdown]
# ## Tamaños de los pesos de toda la red

# %%
weights_dict = np.load('Weights/bvlc_alexnet.npy', encoding='bytes').item()
for k,(w,b) in weights_dict.iteritems():
    print k, b.shape, w.shape
# Out:
# fc6 (4096,) (9216, 4096)
# fc7 (4096,) (4096, 4096)
# fc8 (1000,) (4096, 1000)
# conv3 (384,) (3, 3, 256, 384)
# conv2 (256,) (5, 5, 48, 256)
# conv1 (96,) (11, 11, 3, 96)
# conv5 (256,) (3, 3, 192, 256)
# conv4 (384,) (3, 3, 192, 384)

# %%
alex_w1 = weights_dict["conv1"][0]
alex_w1b = weights_dict["conv1"][1]
print alex_w1.shape
mlutils.display_imgs(alex_w1)
# Out:
# (11, 11, 3, 96)

# %% [markdown]
# ## Transferencia de los pesos y bias

# %%
w = model.get_weights()
w[0] = alex_w1
w[1] = alex_w1b
model.set_weights(w)

# %% [markdown]
# ## Ejecución del modelo con los pesos de la primera capa de AlexNet

# %%
from keras.callbacks import ModelCheckpoint
checkpoint = ModelCheckpoint("model_weights.h5", monitor='val_acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

history = model.fit_generator(generator=generator_train,
                                  epochs=10,
                                  steps_per_epoch=50,
                                  validation_data=generator_test,
                                  validation_steps=40,
                              callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 49/50 [============================>.] - ETA: 2s - loss: 2.0401 - acc: 0.2407
# Epoch 00001: val_acc improved from -inf to 0.34922, saving model to model_weights.h5
# 50/50 [==============================] - 193s 4s/step - loss: 2.0309 - acc: 0.2459 - val_loss: 1.7119 - val_acc: 0.3492
# Epoch 2/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.7289 - acc: 0.3412
# Epoch 00002: val_acc improved from 0.34922 to 0.38281, saving model to model_weights.h5
# 50/50 [==============================] - 189s 4s/step - loss: 1.7260 - acc: 0.3406 - val_loss: 1.5962 - val_acc: 0.3828
# Epoch 3/10
# 49/50 [============================>.] - ETA: 3s - loss: 1.6947 - acc: 0.3642
# Epoch 00003: val_acc improved from 0.38281 to 0.42266, saving model to model_weights.h5
# 50/50 [==============================] - 212s 4s/step - loss: 1.6975 - acc: 0.3625 - val_loss: 1.5363 - val_acc: 0.4227
# Epoch 4/10
# 49/50 [============================>.] - ETA: 3s - loss: 1.6199 - acc: 0.3871
# Epoch 00004: val_acc improved from 0.42266 to 0.46641, saving model to model_weights.h5
# 50/50 [==============================] - 226s 5s/step - loss: 1.6138 - acc: 0.3906 - val_loss: 1.5039 - val_acc: 0.4664
# Epoch 5/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.5638 - acc: 0.4043
# Epoch 00005: val_acc did not improve from 0.46641
# 50/50 [==============================] - 195s 4s/step - loss: 1.5630 - acc: 0.4019 - val_loss: 1.4525 - val_acc: 0.4664
# Epoch 6/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.5146 - acc: 0.4349
# Epoch 00006: val_acc improved from 0.46641 to 0.49609, saving model to model_weights.h5
# 50/50 [==============================] - 200s 4s/step - loss: 1.5114 - acc: 0.4400 - val_loss: 1.3677 - val_acc: 0.4961
# Epoch 7/10
# 49/50 [============================>.] - ETA: 3s - loss: 1.4558 - acc: 0.4681
# Epoch 00007: val_acc improved from 0.49609 to 0.53594, saving model to model_weights.h5
# 50/50 [==============================] - 208s 4s/step - loss: 1.4584 - acc: 0.4688 - val_loss: 1.3308 - val_acc: 0.5359
# Epoch 8/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.4176 - acc: 0.4688
# Epoch 00008: val_acc improved from 0.53594 to 0.56041, saving model to model_weights.h5
# 50/50 [==============================] - 185s 4s/step - loss: 1.4191 - acc: 0.4675 - val_loss: 1.2913 - val_acc: 0.5604
# Epoch 9/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.4182 - acc: 0.4745
# Epoch 00009: val_acc improved from 0.56041 to 0.58359, saving model to model_weights.h5
# 50/50 [==============================] - 172s 3s/step - loss: 1.4193 - acc: 0.4719 - val_loss: 1.2393 - val_acc: 0.5836
# Epoch 10/10
# 49/50 [============================>.] - ETA: 2s - loss: 1.4086 - acc: 0.4770
# Epoch 00010: val_acc did not improve from 0.58359
# 50/50 [==============================] - 172s 3s/step - loss: 1.4103 - acc: 0.4769 - val_loss: 1.2955 - val_acc: 0.5305

# %%
plotevol()

# %% [markdown]
# # Image Oclusion

# %% [markdown]
# Para una imágen satelital se muestra la predicción del modelo todos los sectores lo que presenta como resultado un mapa de calor con las clases predichas en cada sector de la imágen

# %% [markdown]
# ## Descarga de la imágen de prueba
# Se usa una imágen de EarthExplorer para U.S.A del dataset High Resolution Orthoimagery :https://earthexplorer.usgs.gov/

# %%
# !mkdir Examples
# !wget https://ims.cr.usgs.gov/browse/hro/CT/2016/201603_ct_state_block1a_ct_3in_sp_cnir/vol001/855610_nw.jpg -O Examples/img1.jpg
# Out:
# mkdir: cannot create directory ‘Examples’: File exists
# --2019-04-25 01:02:12--  https://ims.cr.usgs.gov/browse/hro/CT/2016/201603_ct_state_block1a_ct_3in_sp_cnir/vol001/855610_nw.jpg
# Resolving ims.cr.usgs.gov (ims.cr.usgs.gov)... 152.61.137.62, 2001:49c8:4000:122c::1062
# Connecting to ims.cr.usgs.gov (ims.cr.usgs.gov)|152.61.137.62|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 63353 (62K) [image/jpeg]
# Saving to: ‘Examples/img1.jpg’
#
# Examples/img1.jpg   100%[===================>]  61.87K   205KB/s    in 0.3s
#
# 2019-04-25 01:02:13 (205 KB/s) - ‘Examples/img1.jpg’ saved [63353/63353]

# %%
img = plt.imread("Examples/img1.jpg")
#aimg = plt.imread("Images/oboe.jpg")
print np.min(img), np.max(img), img.shape
plt.imshow(img)
#plt.axis("off")
# Out:
# 0 255 (512, 512, 3)

# %% [markdown]
# ### Se recorre la imágen prediciendo la clase para sectores de la misma resolución del modelo entrenado

# %%
import mlutils
from numpy import array
predics=[]
w,h=64,64
for i in mlutils.pbar()(range(0,img.shape[0]-w,8)):
    for j in (range(0,img.shape[1]-h,8)):
        oimg = img.copy()
        pimg=oimg[i:i+h,j:j+w]#=np.max(oimg)
        pimg = np.expand_dims(pimg, axis=0)
        #pimg = inception_v3.preprocess_input(np.expand_dims(oimg.astype(float), axis=0))
        pred = model.predict(pimg)
        class_code = np.argsort(pred[0])[::-1][:1]
        predics=np.append(predics,class_code)
# Out:
# 100% (56 of 56) |#########################| Elapsed Time: 0:02:44 Time: 0:02:44

# %%
predics.max(), predics.min(), predics.shape
# Out:
# (7.0, 0.0, (3136,))

# %%
probs=predics.reshape(56,56)
fig, ax = plt.subplots()
a=plt.imshow(probs, cmap='inferno_r')
cbar=fig.colorbar(a)

# %%
from skimage.transform import resize
new_prob=resize(probs, [512, 512])
plt.figure(figsize=(10,6))
plt.subplot(131); plt.imshow(img); plt.axis("off")
plt.subplot(132); plt.imshow(new_prob, cmap='inferno_r'); plt.axis("off")
plt.subplot(133); plt.imshow(img); plt.imshow(new_prob, cmap='inferno_r',alpha=0.4); plt.axis("off")
# Out:
# /opt/miniconda/lib/python2.7/site-packages/skimage/transform/_warps.py:105: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# /opt/miniconda/lib/python2.7/site-packages/skimage/transform/_warps.py:110: UserWarning: Anti-aliasing will be enabled by default in skimage 0.15 to avoid aliasing artifacts when down-sampling images.
#   warn("Anti-aliasing will be enabled by default in skimage 0.15 to "
# (-0.5, 511.5, 511.5, -0.5)

# %% [markdown]
# # Transfer Learning y Fine Tuning
# Se usa el modelo VGG16 para la predicción de las clases de las imágenes

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import PIL
import tensorflow as tf
import numpy as np
import os

from tensorflow.python.keras.models import Model, Sequential
from tensorflow.python.keras.layers import Dense, Flatten, Dropout
from tensorflow.python.keras.applications import VGG16
from tensorflow.python.keras.applications.vgg16 import preprocess_input, decode_predictions
from tensorflow.python.keras.preprocessing.image import ImageDataGenerator
from tensorflow.python.keras.optimizers import Adam, RMSprop
from keras import backend as K
# Out:
# /opt/miniconda/lib/python2.7/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)
# Using TensorFlow backend.
# /opt/miniconda/lib/python2.7/site-packages/requests/__init__.py:80: RequestsDependencyWarning: urllib3 (1.24.1) or chardet (3.0.4) doesn't match a supported version!
#   RequestsDependencyWarning)

# %% [markdown]
# ## Se importa el modelo

# %%
K.clear_session()
 del model
model = VGG16(include_top=True, weights='imagenet')

# %%
input_shape = model.layers[0].output_shape[1:3]
print input_shape
model.summary()
# Out:
# (224, 224)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# _________________________________________________________________
# block3_conv1 (Conv2D)        (None, 56, 56, 256)       295168
# _________________________________________________________________
# block3_conv2 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_conv3 (Conv2D)        (None, 56, 56, 256)       590080
# _________________________________________________________________
# block3_pool (MaxPooling2D)   (None, 28, 28, 256)       0
# _________________________________________________________________
# block4_conv1 (Conv2D)        (None, 28, 28, 512)       1180160
# _________________________________________________________________
# block4_conv2 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_conv3 (Conv2D)        (None, 28, 28, 512)       2359808
# _________________________________________________________________
# block4_pool (MaxPooling2D)   (None, 14, 14, 512)       0
# _________________________________________________________________
# block5_conv1 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv2 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_conv3 (Conv2D)        (None, 14, 14, 512)       2359808
# _________________________________________________________________
# block5_pool (MaxPooling2D)   (None, 7, 7, 512)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# fc1 (Dense)                  (None, 4096)              102764544
# _________________________________________________________________
# fc2 (Dense)                  (None, 4096)              16781312
# _________________________________________________________________
# predictions (Dense)          (None, 1000)              4097000
# =================================================================
# Total params: 138,357,544
# Trainable params: 138,357,544
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Se generan las imágenes

# %%
datagen = ImageDataGenerator(rescale=1./255)

# %%
batch_size = 10 #El tamaño de Batch es el número de imágenes que se pasan por la red en una época
#por lo que se recomienda que el paso en el modelo sea el número de imágenes para test o train según sea el caso
#sobre el batch_size para usar todas las imágenes para entrenar la red y validarla.
generator_train = datagen.flow_from_directory(directory="split/train",
                                                    target_size=input_shape,
                                                    batch_size=batch_size,
                                                    #interpolation = "bilinear",
                                                    class_mode='categorical')
                                                    #shuffle=True)
                                                    #save_to_dir=save_to_dir)
# Out:
# Found 17550 images belonging to 10 classes.

# %%
generator_test = datagen.flow_from_directory(directory="split/test",
                                                  target_size=input_shape,
                                                  batch_size=batch_size,
                                                  #interpolation = "bilinear",
                                                  class_mode='categorical')#,
                                                  #shuffle=False)
# Out:
# Found 9450 images belonging to 10 classes.

# %%
cls_train = generator_train.classes
cls_test = generator_test.classes
class_names = list(generator_train.class_indices.keys())
print class_names
num_classes = generator_train.num_classes
print num_classes
# Out:
# ['Industrial', 'AnnualCrop', 'Residential', 'SeaLake', 'PermanentCrop', 'Forest', 'HerbaceousVegetation', 'Pasture', 'River', 'Highway']
# 10

# %% [markdown]
# ### Se muestran los pesos usados para las diferentes clases, esto depende del número de imágenes que se tienen para train y test, y se pueden modificar para mejorar el desempeño de alguna clase en particular

# %%
from sklearn.utils.class_weight import compute_class_weight

# %%
class_weight = compute_class_weight(class_weight='balanced',
                                    classes=np.unique(cls_train),
                                    y=cls_train)

# %%
class_weight
# Out:
# array([0.9 , 0.9 , 0.9 , 1.08, 1.08, 1.35, 1.08, 0.9 , 1.08, 0.9 ])

# %% [markdown]
# ## Se ajusta un modelo de red densa a la última capa del modelo VGG16

# %%
transfer_layer = model.get_layer('block5_pool')

# %%
transfer_layer.output
# Out:
# <tf.Tensor 'block5_pool/MaxPool:0' shape=(?, 7, 7, 512) dtype=float32>

# %%
from tensorflow.keras import layers,models
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
conv_model = Model(inputs=model.input,
                   outputs=transfer_layer.output)

# %% [markdown]
# ### Arquitectura de las capas no convolucionales para combinar las características del modelo anterior y ajustarlo al número de clases requerido

# %%
# Start a new Keras Sequential model.
new_model = Sequential()

# Add the convolutional part of the VGG16 model from above.
new_model.add(conv_model)

# Flatten the output of the VGG16 model because it is from a
# convolutional layer.
new_model.add(Flatten())

# Add a dense (aka. fully-connected) layer.
# This is for combining features that the VGG16 model has
# recognized in the image.
new_model.add(Dense(1024, activation='relu'))

# Add a dropout-layer which may prevent overfitting and
# improve generalization ability to unseen data e.g. the test-set.
new_model.add(Dropout(0.5))

# Add the final layer for the actual classification.
new_model.add(Dense(num_classes, activation='softmax'))

# %%
optimizer = Adam(lr=1e-5)
loss = 'categorical_crossentropy'
metrics = ['categorical_accuracy']

# %%
new_model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
epochs = 10
steps_per_epoch = 100
new_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# model (Model)                (None, 7, 7, 512)         14714688
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              25691136
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                10250
# =================================================================
# Total params: 40,416,074
# Trainable params: 40,416,074
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Se ejecuta el modelo con las capas entrenables

# %%
history = new_model.fit_generator(generator=generator_train,
                                  epochs=10,
                                  steps_per_epoch=50,
                                  #class_weight=class_weight, #se pueden ajustar los pesos de las categorías
                                  validation_data=generator_test,
                                  validation_steps=40)
# Out:
# Epoch 1/10
# 50/50 [==============================] - 541s 11s/step - loss: 2.1352 - acc: 0.2560 - val_loss: 1.4407 - val_acc: 0.5125
# Epoch 2/10
# 50/50 [==============================] - 504s 10s/step - loss: 1.4692 - acc: 0.4620 - val_loss: 0.9968 - val_acc: 0.6850
# Epoch 3/10
# 50/50 [==============================] - 518s 10s/step - loss: 1.0096 - acc: 0.6180 - val_loss: 0.8143 - val_acc: 0.7075
# Epoch 4/10
# 37/50 [=====================>........] - ETA: 1:49 - loss: 0.8899 - acc: 0.6703

# %%
plotevol()

# %% [markdown]
# ## La arquitectura se pone como no entrenable para usar el modelo con los pesos y bias

# %%
K.clear_session()
del model
model = VGG16(include_top=True, weights='imagenet')

# %%
input_shape = model.layers[0].output_shape[1:3]
print input_shape
model.summary()

# %%
transfer_layer = model.get_layer('block5_pool')

# %%
transfer_layer.output

# %%
from tensorflow.keras import layers,models
from keras.preprocessing.image import ImageDataGenerator
import tensorflow as tf
conv_model = Model(inputs=model.input,
                   outputs=transfer_layer.output)

# %%
# Start a new Keras Sequential model.
new_model = Sequential()

# Add the convolutional part of the VGG16 model from above.
new_model.add(conv_model)

# Flatten the output of the VGG16 model because it is from a
# convolutional layer.
new_model.add(Flatten())

# Add a dense (aka. fully-connected) layer.
# This is for combining features that the VGG16 model has
# recognized in the image.
new_model.add(Dense(1024, activation='relu'))

# Add a dropout-layer which may prevent overfitting and
# improve generalization ability to unseen data e.g. the test-set.
new_model.add(Dropout(0.5))

# Add the final layer for the actual classification.
new_model.add(Dense(num_classes, activation='softmax'))

# %%
def print_layer_trainable():
    for layer in conv_model.layers:
        print("{0}:\t{1}".format(layer.trainable, layer.name))

# %%
print_layer_trainable()

# %%
conv_model.trainable = False

# %%
for layer in conv_model.layers:
    layer.trainable = False

# %%
print_layer_trainable()

# %%
new_model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = new_model.fit_generator(generator=generator_train,
                                  epochs=10,
                                  steps_per_epoch=50,
                                  class_weight=class_weight,
                                  validation_data=generator_test,
                                  validation_steps=40)

# %%
plotevol()

# %% [markdown]
# ## Image Oclusion con VGG16

# %%
img = plt.imread("Examples/img2.jpg")
#aimg = plt.imread("Images/oboe.jpg")
print np.min(img), np.max(img), img.shape
plt.imshow(img)
#plt.axis("off")

# %% [markdown]
# ### Se recorre la imágen prediciendo la clase para sectores de la misma resolución del modelo entrenado

# %%
from keras.preprocessing import image
from PIL import Image 
import mlutils
from numpy import array
predics=[]
w,h=64,64

for i in mlutils.pbar()(range(0,img.shape[0]-w,32)):
    for j in (range(0,img.shape[1]-h,32)):
        oimg = img.copy()
        pimg=oimg[i:i+h,j:j+w]#=np.max(oimg)
        simg = Image.fromarray(pimg, 'RGB')
        simg.save('my.png')
        pimg = image.load_img('my.png', target_size=(224, 224)) #la imagen se ajusta al modelo VGG16
        pimg = np.expand_dims(pimg, axis=0)
        #print pimg.shape
        #pimg = inception_v3.preprocess_input(np.expand_dims(oimg.astype(float), axis=0))
        pred = new_model.predict(pimg, steps=3)
        class_code = np.argsort(pred[0])[::-1][:1]
        predics=np.append(predics,class_code)

# %%
img.shape[1]/img.shape[0]
# Out:
# 2

# %%
predics.max(), predics.min()
# Out:
# (9.0, 0.0)

# %%
probs=predics.reshape(21,46)
fig, ax = plt.subplots()
a=plt.imshow(probs, cmap='inferno_r')
cbar=fig.colorbar(a)

# %%
from skimage.transform import resize
new_prob=resize(probs, [718,1524])#[512, 512])
plt.figure(figsize=(10,6))
plt.subplot(131); plt.imshow(img); plt.axis("off")
plt.subplot(132); plt.imshow(new_prob, cmap='inferno_r'); plt.axis("off")
plt.subplot(133); plt.imshow(img); plt.imshow(new_prob, cmap='inferno_r',alpha=0.4); plt.axis("off")
# Out:
# (-0.5, 1523.5, 717.5, -0.5)

# %% [markdown]
# ## Se observa que con el model construido se llega a un desempeño de 39.29%, con los pesos de AlexNet en la primera capa a un 55.4% y con la arquitectura VGG16 a un 91%
